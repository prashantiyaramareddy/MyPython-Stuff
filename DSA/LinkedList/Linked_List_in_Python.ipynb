# %% [markdown]
# <a href="https://colab.research.google.com/github/prashantiyaramareddy/AI-ML-Learnings/blob/master/DSA/LinkedList/Linked_List_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Simple Linked List implementation in Python

# %%
class Node:
    def __init__(self, k):
        self.key = k
        self.next = None


temp1 = Node(10)
temp2 = Node(20)
temp3 = Node(30)

temp1.next = temp2
temp2.next = temp3

head = temp1
print(head.key)
print(head.next.key)
print(head.next.next.key)
# Out:
# 10
# 20
# 30

# %% [markdown]
# ### Tranversal of LinkedLIst

# %%
class Node:
    def __init__(self, key):
        self.key = key
        self.next = None


def printList(head):
    curr = head
    while curr!= None:
        print(curr.key)
        curr = curr.next


head = Node(10)
head.next = Node(20)
head.next.next = Node(15)
head.next.next.next = Node(30)
printList(head)
# Out:
# 10
# 20
# 15
# 30

# %% [markdown]
# Time Complexity: Worst and Average Case
#
# *   Search   - O(n)
# *   Insert   - O(n)
# *   Deletion - O(n)
#
# Auxillary Space: O(1)

# %% [markdown]
# ### Search in Linked List

# %%
class Node:
  def __init__(self, k):
    self.key = k
    self.next = None

  def search(head, x):
    pos = 1
    curr = head
    while curr != None:
      if curr.key == x:
        return pos
      pos = pos + 1
      curr = curr.next
    return -1


head = Node(10)
head.next = Node(20)
head.next.next = Node(15)
head.next.next.next = Node(30)
print(Node.search(head, 15))
# Out:
# 3

# %% [markdown]
# ### Time Complexity  and Auxillary Space of Search in Linkedlist

# %% [markdown]
# Time Complexity - O(n)
#
# Auxillary Space - O(1)

# %% [markdown]
# ### Insert at the beginning of Linked List in Python

# %%
class Node:
  def __init__(self, key):
    self.key = key
    self.next = None

  def insertBegin(head, key):
    temp = Node(key)
    temp.next = head
    return temp


  def printList(head):
    curr = head
    while curr!= None:
        print(curr.key)
        curr = curr.next

# Driver code
head = None
head = Node.insertBegin(head, 10)
head = Node.insertBegin(head, 20)
head = Node.insertBegin(head, 30)
head = Node.insertBegin(head, 40)
Node.printList(head)
# Out:
# 40
# 30
# 20
# 10

# %% [markdown]
# ### Time Complexity for insering at the beginning
#
# * Time Complexity: O(1), We have a pointer to the head and we can directly attach a node and change the pointer. So the Time complexity of inserting a node at the head position is O(1) as it does a constant amount of work.
#
# * Auxiliary Space: O(1)

# %% [markdown]
# ### Inserting at the end of the linked list

# %%
class Node:
  def __init__(self, key):
    self.key = key
    self.next = None

  def insertEnd(head, key):
    new_node = Node(key)
    if head is None:
      return new_node

    curr = head
    while curr.next != None:
      curr = curr.next
    curr.next = new_node
    return head


  def printList(head):
    curr = head
    while curr!= None:
        print(curr.key)
        curr = curr.next

# Driver code
head = None
head = Node.insertEnd(head, 10)
head = Node.insertEnd(head, 20)
head = Node.insertEnd(head, 30)
head = Node.insertEnd(head, 40)
Node.printList(head)
# Out:
# 10
# 20
# 30
# 40

# %% [markdown]
# Complexity Analysis:
#
# * Time complexity: O(N), where N is the number of nodes in the linked list. Since there is a loop from head to end, the function does O(n) work.
# This method can also be optimized to work in O(1) by keeping an extra pointer to the tail of the linked list/
#
# * Auxiliary Space: O(1)
